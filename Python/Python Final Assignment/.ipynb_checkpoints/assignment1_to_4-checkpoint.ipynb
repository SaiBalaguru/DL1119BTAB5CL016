# %%
import pandas as pd
dffb = pd.read_csv('results.csv')
dffb
# Out:
#              date     home_team    away_team  home_score  away_score  \
# 0      1872-11-30      Scotland      England           0           0
# 1      1873-03-08       England     Scotland           4           2
# 2      1874-03-07      Scotland      England           2           1
# 3      1875-03-06       England     Scotland           2           2
# 4      1876-03-04      Scotland      England           3           0
# ...           ...           ...          ...         ...         ...
# 41535  2019-11-19    Kyrgyzstan   Tajikistan           1           1
# 41536  2019-11-19       Vietnam     Thailand           0           0
# 41537  2019-11-19      Malaysia    Indonesia           2           0
# 41538  2019-11-19  Turkmenistan    Sri Lanka           2           0
# 41539  2019-11-19       Lebanon  North Korea           0           0
#
#                          tournament          city       country  neutral
# ...

# %%
print("The Matches played at London")
dffb[(dffb.tournament == "FIFA World Cup qualification") & (dffb.city == "Beirut")]
# Out:
# The Matches played at London
#              date  home_team             away_team  home_score  away_score  \
# 17658  1993-05-07  Hong Kong               Bahrain           2           1
# 17659  1993-05-07    Lebanon                 India           2           2
# 17662  1993-05-09    Bahrain           South Korea           0           0
# 17665  1993-05-09    Lebanon             Hong Kong           2           2
# 17666  1993-05-11      India             Hong Kong           1           2
# 17667  1993-05-11    Lebanon           South Korea           0           1
# 17671  1993-05-13      India           South Korea           0           3
# 17672  1993-05-13    Lebanon               Bahrain           0           0
# 17675  1993-05-15    Bahrain                 India           2           1
# 17676  1993-05-15  Hong Kong           South Korea           0           3
# 20386  1997-04-13    Lebanon             Singapore           1           1
# ...

# %%
print("The away Team is India & They scored more than 5 goals!")
dffb[(dffb.away_team == 'India') & (dffb.away_score>=5)]
# Out:
# The away Team is India & They scored more than 5 goals!
#             date  home_team away_team  home_score  away_score tournament  \
# 4067  1956-12-12  Australia     India           1           7   Friendly
# 7537  1970-08-19  Singapore     India           3           8   Friendly
# 8706  1973-08-15  Singapore     India           4           5   Friendly
#
#          city    country  neutral
# 4067   Sydney  Australia    False
# 7537  Kallang  Singapore    False
# 8706  Kallang  Singapore    False

# %%
print("All Neutral Games played by Brazil in Argentina")
dffb[(dffb.neutral == True) & (dffb.home_team == 'Brazil')& (dffb.country == "Argentina")]
# Out:
# All Neutral Games played by Brazil in Argentina
#              date home_team  away_team  home_score  away_score  \
# 434    1916-07-08    Brazil      Chile           1           1
# 437    1916-07-12    Brazil    Uruguay           1           2
# 603    1921-10-12    Brazil   Paraguay           3           0
# 606    1921-10-23    Brazil    Uruguay           1           2
# 929    1925-12-06    Brazil   Paraguay           5           2
# 933    1925-12-17    Brazil   Paraguay           3           1
# 1923   1936-12-27    Brazil       Peru           3           2
# 1926   1937-01-03    Brazil      Chile           6           4
# 1936   1937-01-13    Brazil   Paraguay           5           0
# 1939   1937-01-19    Brazil    Uruguay           3           2
# 2562   1946-01-23    Brazil    Uruguay           4           3
# 2567   1946-01-29    Brazil   Paraguay           1           1
# 2569   1946-02-03    Brazil      Chile           5           1
# ...

# %%
print("Matches in which no goal was scored in FIFA World Cu[p Qualifications]")
dffb[(dffb.home_score == 0) & (dffb.away_score == 0)& (dffb.tournament=="FIFA World Cup qualification")]
# Out:
# Matches in which no goal was scored
#              date       home_team         away_team  home_score  away_score  \
# 3065   1950-03-08           Wales  Northern Ireland           0           0
# 3561   1953-11-08  Czechoslovakia          Bulgaria           0           0
# 3562   1953-11-08        Saarland            Norway           0           0
# 3577   1953-11-29        Portugal           Austria           0           0
# 4131   1957-05-05          Greece        Yugoslavia           0           0
# ...           ...             ...               ...         ...         ...
# 41403  2019-11-14       Hong Kong           Bahrain           0           0
# 41412  2019-11-14         Lebanon       South Korea           0           0
# 41528  2019-11-19            Iraq           Bahrain           0           0
# 41536  2019-11-19         Vietnam          Thailand           0           0
# 41539  2019-11-19         Lebanon       North Korea           0           0
#
# ...
